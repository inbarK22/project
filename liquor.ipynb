# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\inbar\\OneDrive - Ariel University\\my_notebook\\tirgulim'

# %%
path = 'Iowa Liquor Sales (Jan 2021-Jan 2022).csv'
pd.read_csv(path)
# Out:
#         invoice_and_item_number        date  store_number  \
# 0               INV-33179700135  2021-01-04          2576
# 1               INV-33196200106  2021-01-04          2649
# 2               INV-33184300011  2021-01-04          2539
# 3               INV-33184100015  2021-01-04          4024
# 4               INV-33174200025  2021-01-04          5385
# ...                         ...         ...           ...
# 2805302         INV-41968600007  2021-11-14          4617
# 2805303         INV-41968600008  2021-11-14          4617
# 2805304         INV-41968600009  2021-11-14          4617
# 2805305         INV-41968600006  2021-11-14          4617
# 2805306         INV-41968600005  2021-11-14          4617
#
#                                    store_name           address  \
# 0        Hy-Vee Wine and Spirits / Storm Lake    1250 N Lake St
# 1                         Hy-Vee #3 / Dubuque     400 Locust St
# 2              Hy-Vee Food Store / Iowa Falls        640 S. Oak
# ...

# %%
# קריאת הקובץ המקורי
large_csv_file = 'Iowa Liquor Sales (Jan 2021-Jan 2022).csv'

chunk_size = 100000  # גודל חלק רצוי
# 89184 rows × 83 columns

# קריאת הקובץ בגודלי חלקים ושמירתם כקבצים נפרדים
for i, chunk in enumerate(pd.read_csv(large_csv_file, chunksize=chunk_size)):
    chunk.to_csv(f'C:\\Users\\inbar\OneDrive - Ariel University\\my_notebook\\tirgulim\\big_data\\Iowa Liquor Sales (Jan 2021-Jan 2022){i}.csv', index=False)

# %%
# DataFrame ריק כדי לאחסן את כל הדאטה
csv_files = ['https://raw.githubusercontent.com/inbarK22/project/main/Iowa%20Liquor%20Sales%20(Jan%202021-Jan%202022)0.csv', 'https://raw.githubusercontent.com/inbarK22/project/main/Iowa%20Liquor%20Sales%20(Jan%202021-Jan%202022)1.csv' , 'https://raw.githubusercontent.com/inbarK22/project/main/Iowa%20Liquor%20Sales%20(Jan%202021-Jan%202022)2.csv' , 'https://raw.githubusercontent.com/inbarK22/project/main/Iowa%20Liquor%20Sales%20(Jan%202021-Jan%202022)3.csv' , 'https://raw.githubusercontent.com/inbarK22/project/main/Iowa%20Liquor%20Sales%20(Jan%202021-Jan%202022)4.csv' , 'https://raw.githubusercontent.com/inbarK22/project/main/Iowa%20Liquor%20Sales%20(Jan%202021-Jan%202022)5.csv' , 'https://raw.githubusercontent.com/inbarK22/project/main/Iowa%20Liquor%20Sales%20(Jan%202021-Jan%202022)6.csv' , 'https://raw.githubusercontent.com/inbarK22/project/main/Iowa%20Liquor%20Sales%20(Jan%202021-Jan%202022)7.csv' , 'https://raw.githubusercontent.com/inbarK22/project/main/Iowa%20Liquor%20Sales%20(Jan%202021-Jan%202022)8.csv' , 'https://raw.githubusercontent.com/inbarK22/project/main/Iowa%20Liquor%20Sales%20(Jan%202021-Jan%202022)9.csv' , 'https://raw.githubusercontent.com/inbarK22/project/main/Iowa%20Liquor%20Sales%20(Jan%202021-Jan%202022)10.csv' , 'https://raw.githubusercontent.com/inbarK22/project/main/Iowa%20Liquor%20Sales%20(Jan%202021-Jan%202022)11.csv' , 'https://raw.githubusercontent.com/inbarK22/project/main/Iowa%20Liquor%20Sales%20(Jan%202021-Jan%202022)12.csv' , 'https://raw.githubusercontent.com/inbarK22/project/main/Iowa%20Liquor%20Sales%20(Jan%202021-Jan%202022)13.csv' , 'https://raw.githubusercontent.com/inbarK22/project/main/Iowa%20Liquor%20Sales%20(Jan%202021-Jan%202022)14.csv' , 'https://raw.githubusercontent.com/inbarK22/project/main/Iowa%20Liquor%20Sales%20(Jan%202021-Jan%202022)15.csv' , 'https://raw.githubusercontent.com/inbarK22/project/main/Iowa%20Liquor%20Sales%20(Jan%202021-Jan%202022)16.csv' , 'https://raw.githubusercontent.com/inbarK22/project/main/Iowa%20Liquor%20Sales%20(Jan%202021-Jan%202022)17.csv' , 'https://raw.githubusercontent.com/inbarK22/project/main/Iowa%20Liquor%20Sales%20(Jan%202021-Jan%202022)18.csv' , 'https://raw.githubusercontent.com/inbarK22/project/main/Iowa%20Liquor%20Sales%20(Jan%202021-Jan%202022)19.csv' , 'https://raw.githubusercontent.com/inbarK22/project/main/Iowa%20Liquor%20Sales%20(Jan%202021-Jan%202022)20.csv' , 'https://raw.githubusercontent.com/inbarK22/project/main/Iowa%20Liquor%20Sales%20(Jan%202021-Jan%202022)21.csv' , 'https://raw.githubusercontent.com/inbarK22/project/main/Iowa%20Liquor%20Sales%20(Jan%202021-Jan%202022)22.csv' , 'https://raw.githubusercontent.com/inbarK22/project/main/Iowa%20Liquor%20Sales%20(Jan%202021-Jan%202022)23.csv' , 'https://raw.githubusercontent.com/inbarK22/project/main/Iowa%20Liquor%20Sales%20(Jan%202021-Jan%202022)24.csv' , 'https://raw.githubusercontent.com/inbarK22/project/main/Iowa%20Liquor%20Sales%20(Jan%202021-Jan%202022)25.csv' , 'https://raw.githubusercontent.com/inbarK22/project/main/Iowa%20Liquor%20Sales%20(Jan%202021-Jan%202022)26.csv' , 'https://raw.githubusercontent.com/inbarK22/project/main/Iowa%20Liquor%20Sales%20(Jan%202021-Jan%202022)27.csv' , 'https://raw.githubusercontent.com/inbarK22/project/main/Iowa%20Liquor%20Sales%20(Jan%202021-Jan%202022)28.csv' ]

merged_df = pd.DataFrame()

# עבור כל קישור, קרא את הקובץ CSV והוסף את הדאטה ל-DataFrame הראשי
for link in csv_files:
    df = pd.read_csv(link)
    merged_df = pd.concat([merged_df, df], ignore_index=True)

# %%
merged_df
# Out:
#         invoice_and_item_number        date  store_number  \
# 0               INV-33179700135  2021-01-04          2576
# 1               INV-33196200106  2021-01-04          2649
# 2               INV-33184300011  2021-01-04          2539
# 3               INV-33184100015  2021-01-04          4024
# 4               INV-33174200025  2021-01-04          5385
# ...                         ...         ...           ...
# 2805302         INV-41968600007  2021-11-14          4617
# 2805303         INV-41968600008  2021-11-14          4617
# 2805304         INV-41968600009  2021-11-14          4617
# 2805305         INV-41968600006  2021-11-14          4617
# 2805306         INV-41968600005  2021-11-14          4617
#
#                                    store_name           address  \
# 0        Hy-Vee Wine and Spirits / Storm Lake    1250 N Lake St
# 1                         Hy-Vee #3 / Dubuque     400 Locust St
# 2              Hy-Vee Food Store / Iowa Falls        640 S. Oak
# ...

# %%
path = 'Iowa Liquor Sales (Jan 2021-Jan 2022).csv'
pd.read_csv(path)
# Out:
#         invoice_and_item_number        date  store_number  \
# 0               INV-33179700135  2021-01-04          2576
# 1               INV-33196200106  2021-01-04          2649
# 2               INV-33184300011  2021-01-04          2539
# 3               INV-33184100015  2021-01-04          4024
# 4               INV-33174200025  2021-01-04          5385
# ...                         ...         ...           ...
# 2805302         INV-41968600007  2021-11-14          4617
# 2805303         INV-41968600008  2021-11-14          4617
# 2805304         INV-41968600009  2021-11-14          4617
# 2805305         INV-41968600006  2021-11-14          4617
# 2805306         INV-41968600005  2021-11-14          4617
#
#                                    store_name           address  \
# 0        Hy-Vee Wine and Spirits / Storm Lake    1250 N Lake St
# 1                         Hy-Vee #3 / Dubuque     400 Locust St
# 2              Hy-Vee Food Store / Iowa Falls        640 S. Oak
# ...

# %%
print(merged_df.head())
print(merged_df.info())
# Out:
#   invoice_and_item_number        date  store_number  \
# 0         INV-33179700135  2021-01-04          2576
# 1         INV-33196200106  2021-01-04          2649
# 2         INV-33184300011  2021-01-04          2539
# 3         INV-33184100015  2021-01-04          4024
# 4         INV-33174200025  2021-01-04          5385
#
#                              store_name         address             city  \
# 0  Hy-Vee Wine and Spirits / Storm Lake  1250 N Lake St       Storm Lake
# 1                   Hy-Vee #3 / Dubuque   400 Locust St          Dubuque
# 2        Hy-Vee Food Store / Iowa Falls      640 S. Oak       Iowa Falls
# 3            Wal-Mart 1546 / Iowa Falls       840 S Oak       Iowa Falls
# 4                    Vine Food & Liquor   2704 Vine St.  West Des Moines
#
#    zip_code                        store_location  county_number      county  \
# 0   50588.0  POINT (-95.200758 42.65318400000001)           11.0  BUENA VIST
# ...
